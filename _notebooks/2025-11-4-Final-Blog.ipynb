# %% [markdown]
# ---
# Layout: post
# title: Final Blog
# description: Final blog for tri 1
# catagories: [End of tri, blog]
# permalink: /endoftriblog
# ---

# %% [markdown]
# ## End of trimester blog

# %% [markdown]
# In the begining of the year I did not know anything abut coding, terminal, or what vs code was. When we first started I was very confused on how to install everything we would need for this clss. I also didnt know how to do any coding when we started our first assignment. I didnt know anything when we started oir projet and I needed lots of help from others to make it easier for me. Over time I slowly learned more about coding and how to work in the terminal, as well as working in vs code. I Also learned more on how to code by my self and didnt require as much help from others as I did in the begining of the year. I also learned how to incorporate AI into my code to make it easier and faster to make. I also learned that I shouldnt rely on just AI becuase AI can make lots of mistakes and it would be harder to fix, so I only use AI to make a little bit of code and I would fix the code and add more to it and make it work.

# %% [markdown]
# ## Three key thing I remember

# %% [markdown]
# Some key things I remember are Classes which are things whwere you can store many different variables. I also rember variable which are things that you assign values to so when you put that variable it follows through with whatever value you gave it. The third thing I learned is using the terminal, I learned how to use terminal to open vs code and also set up repositories. I also learned How to navigate in the terminal which commands like ls and cd. These little things I learned made by coding experience easier and better.

# %% [markdown]
# ## How Night at the museun went

# %% [markdown]
# I liked how many people were interested in our game and were giving lots of advice to make our game better. I also liked the many different comments that were left. I also liked checking out other peoples games and seeing how theirs were better that ours and how We could incorporate some of their ideas into our game to make it better. I Also liked seeing everone there all presenting what they made.

# %% [markdown]
# ## Next project

# %% [markdown]
# If I was given time I would want to make our game better and try to improve differetn aspects of our current game. I would also look at the comments that we got and implememnt those ideas into our game to hopefully make it better. I would really like to make this game  much better that it is right now and with less bugs and also make different cool things that could make better. If I would have to make another project I would probably want to make a game where you play as a charecter who goes around to collect different weapons by defeating enemies and go on to eventually fight a final boss that would finsih the game.

# %% [markdown]
# ## What I want to learn next

# %% [markdown]
# I want to learn more about coding and the different languages of coding. I also want to learn coding in more depth and learn different small things that could make coding easier and also make code better. I would also want to see how other coders make their code better and see what little chnages I can make to my code to make it a better experience for me as well as the user.
